# %%
import pandas as pd
import numpy as np
import math
from IPython.display import Markdown, display

# %%
from google.colab import drive
drive.mount('/content/drive')

path = "/content/drive/MyDrive/DataScience"
# Out:
# Mounted at /content/drive

# %%
dados = pd.read_csv(path + '/age_dataset.csv', sep=',')

dados.head(10)
# Out:
#      Id                       Name  \
# 0   Q23          George Washington
# 1   Q42              Douglas Adams
# 2   Q91            Abraham Lincoln
# 3  Q254    Wolfgang Amadeus Mozart
# 4  Q255       Ludwig van Beethoven
# 5  Q260  Jean-François Champollion
# 6  Q272                Paul Morand
# 7  Q296               Claude Monet
# 8  Q297            Diego Velázquez
# 9  Q301                   El Greco
#
#                                  Short description Gender  \
# 0   1st president of the United States (1732–1799)   Male
# 1                      English writer and humorist   Male
# 2  16th president of the United States (1809-1865)   Male
# 3        Austrian composer of the Classical period   Male
# 4           German classical and romantic composer   Male
# 5                         French classical scholar   Male
# 6                                    French writer   Male
# 7         French impressionist painter (1840-1926)   Male
# ...

# %%
esportistas = [
    "Athlete",
    "Racing automobile driver",
    "Formula one driver",
    "Racing automobile driver; formula one driver",
    "Karateka",
    "Fencer",
    "Sprinter"
]

# %%
artist = dados[dados['Occupation'].isin(esportistas)]

artist.shape
# Out:
# (112880, 10)

# %%
artist.head(10)
# Out:
#         Id                                 Name  \
# 16    Q354                           Piet Kraak
# 19    Q379                   František Plánička
# 169  Q1625                      Sigfrid Edström
# 170  Q1628  David Cecil, 6th Marquess of Exeter
# 172  Q1634                       Adriaan Paulen
# 173  Q1638                        Primo Nebiolo
# 188  Q2001                      Stanley Kubrick
# 191  Q2040                      Giuseppe Farina
# 195  Q2104                        Mike Hawthorn
# 199  Q2125                         Jack Brabham
#
#                                      Short description Gender  \
# 16                        Dutch footballer (1921-1984)   Male
# 19       Czech association football player (1904-1996)   Male
# 169  Swedish industrialist and International Olympi...   Male
# 170  English athlete, sports official, and Conserva...   Male
# 172  Dutch athlete and president of the IAAF (1902-...   Male
# ...
